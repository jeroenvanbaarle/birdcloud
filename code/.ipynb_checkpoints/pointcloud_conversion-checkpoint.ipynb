# %%
import math
import time
import os
from datetime import datetime

import h5py
import numpy as np
import pandas as pd
import polars as pl
import wradlib
import xarray as xr
import parquet
from numba import jit
from threading import Thread
from multiprocessing import Pool
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
class BirdCloud:

    def __init__(self):
        """
        Prepares BirdCloud object

        The object contains radar, product and projection metadata and a potentially range limited point cloud.
        """
        self.source = None
        self.radar = dict()
        self.product = dict()
        self.scans = dict()
        self.pointcloud = None
        self.range_limit = None
        self.projection = None
        self._elevations = []

    def from_odim_file(self, filepath, range_limit=None, dr_thresh=-12):
        """
        Builds point cloud from ODIM formatted polar volume

        :param filepath: path to the ODIM formatted HDF5 file
        :param range_limit: None or iterable containing both minimum and maximum range of the point cloud from the radar
            site.
        :param dr_thresh: Threshold of depolarization ratio to label biology and meteorology. Values above this
            threshold will be labeled as biology.
        """
        f = h5py.File(filepath, 'r')
        self.source = filepath
        self.range_limit = range_limit

        self.parse_odim_metadata(f)
        self.extract_odim_scans(f)
        self.calculate_additional_metrics()
        self.label_biology_using_depolarization_ratio(thresh=dr_thresh)
        self.flatten_scans_to_pointcloud()
        self.drop_na_rows()
        self.drop_center_points()
        self.set_column_order()
        self.remove_columns()
        #self.to_parquet(r"C:\Users\Jeroen\Documents\Studie\Master\Thesis\pointclouds\")

    def parse_odim_metadata(self, file):
        """
        Parses ODIM metadata from HDF5 file about radar itself and the provided radar products

        Volume scan start and end times are derived from start time of the 1st scan and end time of the 16th scan, as
        scans are numbered chronologically.
        :param file: ODIM formatted HDF5 file object
        """
        source = dict(pair.split(':') for pair in file['what'].attrs.get('source').decode('UTF-8').split(','))
        self.radar['name'] = source['PLC'].replace(" ", "") if source.get('PLC') is not None else source.get('WMO')
        self.radar['latitude'] = file['where'].attrs.get('lat')[0]
        self.radar['longitude'] = file['where'].attrs.get('lon')[0]
        self.radar['altitude'] = file['where'].attrs.get('height')[0]
        self.radar['polarization'] = self.radar_metadata[self.radar['name']]['polarization']

        time_start = datetime.strptime(file['dataset1']['what'].attrs.get('starttime').decode('UTF-8'), '%H%M%S').time()
        date_start = datetime.strptime(file['dataset1']['what'].attrs.get('startdate').decode('UTF-8'), '%Y%m%d').date()
        self.product['datetime_start'] = datetime.combine(date_start, time_start)
        time_end = datetime.strptime(file['dataset16']['what'].attrs.get('endtime').decode('UTF-8'), '%H%M%S').time()
        date_end = datetime.strptime(file['dataset16']['what'].attrs.get('enddate').decode('UTF-8'), '%Y%m%d').date()
        self.product['datetime_end'] = datetime.combine(date_end, time_end)

    def extract_odim_scans(self, file):
        """
        Iterates over all scans and corresponding datasets in the ODIM formatted HDF5 files and stores all scans in
        self.scans dictionary as Xarray Datasets, accessible by elevation keys.

        :param file: ODIM formatted HDF5 file object
        """
        for group in file:
            if not file[group].name.startswith('dataset', 1):
                continue

            if file[group].name in self.excluded_scans:
                continue

            elevation = round(file[group]['where'].attrs.get('elangle')[0], 1)
            n_range_bins = file[group]['where'].attrs.get('nbins')[0]
            n_azim_bins = file[group]['where'].attrs.get('nrays')[0]
            bin_range = file[group]['where'].attrs.get('rscale')[0] / 1000
            site_coords = [self.radar['longitude'], self.radar['latitude'], self.radar['altitude'] / 1000]

            bin_range_min, bin_range_max = self.calculate_bin_range_limits(self.range_limit, bin_range, n_range_bins)

            x, y, z, ranges, azimuths = self.calculate_xyz(site_coords, elevation, n_azim_bins,
                                                           bin_range, bin_range_min, bin_range_max)

            datasets = {}

            for dataset in file[group]:
                try:
                    ds, quantity = self.parse_odim_dataset(file[group][dataset], bin_range_min, bin_range_max,
                                                           ranges, azimuths)

                    datasets[quantity] = ds

                except TypeError:
                    continue

            dataset = xr.Dataset(data_vars=datasets,
                                 coords={'azimuth': azimuths,
                                         'range': ranges,
                                         'x': (['azimuth', 'range'], x),
                                         'y': (['azimuth', 'range'], y),
                                         'z': (['azimuth', 'range'], z)},
                                 attrs={'elevation': elevation,
                                        'n_range_bins': n_range_bins,
                                        'n_azim_bins': n_azim_bins,
                                        'bin_range': bin_range})

            self.scans[str(elevation)] = dataset
            self._elevations.append(elevation)
    
    def parse_odim_dataset(self, dataset, bin_range_min, bin_range_max, ranges, azimuths):
        """
        Parses a single dataset within a scan by converting it using the calibration formula and storing it as an
        Xarray DataArray.

        All missing data is marked as np.nan.

        :param dataset: ODIM HDF5 file object with path to a radar dataset
        :param bin_range_min: the index of the first bin that falls within the instance range_limit
        :param bin_range_max: the index of the last bin that falls within the instance range_limit
        :param ranges: grid of range values corresponding to each of the cells in the dataset array
        :param azimuths: grid of azimuth values corresponding to each of the cells in the dataset array
        :return: converted ODIM dataset as Xarray DataArray and corresponding product (quantity) name
        """
        dataset_name = dataset.name.replace(dataset.parent.name + '/', '')

        if not dataset_name.startswith('data'):
            return None

        quantity = dataset['what'].attrs.get('quantity').decode('UTF-8')

        if quantity in self.excluded_datasets[self.radar['polarization']]:
            return None

        gain = dataset['what'].attrs.get('gain')[0]
        offset = dataset['what'].attrs.get('offset')[0]
        nodata = dataset['what'].attrs.get('nodata')[0]
        undetect = dataset['what'].attrs.get('undetect')[0]

        raw_data = dataset['data'][:, bin_range_min:bin_range_max]
        missing = np.logical_or(raw_data == nodata, raw_data == undetect)

        corrected_data = raw_data * gain + offset
        corrected_data[missing] = np.nan

        ds = xr.DataArray(corrected_data, coords=[azimuths, ranges], dims=['azimuth', 'range'])

        return ds, quantity

    def calculate_bin_range_limits(self, range_limit, bin_range, n_range_bins):
        """
        Calculates range of bins to select for all to fall within provided range_limit.

        If the lower limit is None, it will be converted to 0. If the upper limit is None, it will be converted to the
        maximum value of the range, i.e. n_range_bins.

        E.g. this function will return the 6th bin as bins_min if the minimum range limit is set to 5 (km) and the
            bin_range is 0.900: 5/0.900 = 5.5555 -> 6

        :param range_limit: iterable containing successively a minimum and maximum range
        :param bin_range: range covered by a single bin in the same units as range_limit
        :param n_range_bins: the number of range bins within a scan
        :return: indexes for the first (bins_min) and last (bins_max) bins that fall within the given range_limit
        """
        if range_limit is None:
            range_limit = [None, None]

        minimum = range_limit[0] if range_limit[0] is not None else 0
        maximum = range_limit[1] if range_limit[1] is not None else n_range_bins

        bins_min = math.ceil(minimum / bin_range)
        if bins_min > n_range_bins:
            raise ValueError('Minimum range set too high: no datapoints remaining.')

        bins_max = math.floor(maximum / bin_range)
        if bins_max > n_range_bins:
            bins_max = n_range_bins

        return bins_min, bins_max

    def calculate_xyz(self, sitecoords, elevation_angle, n_azim_bins, bin_range, bin_range_min, bin_range_max):
        """
        Calculates X, Y and Z coordinates for centers of all radar bins using wradlib and sets self.projection to the
        corresponding georeferencing information.

        :param sitecoords: iterable containing coordinates and altitude of radar site, in the order of: longitude,
            latitude, altitude
        :param elevation_angle: elevation angle of the radar scan
        :param n_azim_bins: number of azimuthal bins of the radar scan (usually 360)
        :param bin_range: range covered by every bin (usually in kilometers). Should be in the same units as the radar
            altitude
        :param bin_range_min: index of the first range bin to calculate X, Y and Z coordinates for
        :param bin_range_max: index of the last range bin to calculate X, Y and Z coordinates for
        :return: numpy arrays for the X, Y and Z coordinates and ranges and azimuths
        """
        if sitecoords is None:
            sitecoords = (0, 0)

        n_range_bins = bin_range_max - bin_range_min
        range_min = bin_range_min * bin_range
        range_max = bin_range_max * bin_range
        ranges = np.linspace(range_min, range_max, n_range_bins)
        azimuths = np.arange(0, n_azim_bins)

        polargrid = np.meshgrid(ranges, azimuths)

        xyz, self.projection = wradlib.georef.polar.spherical_to_xyz(polargrid[0], polargrid[1], elevation_angle,
                                                                     sitecoords, re=6378000, squeeze=True)

        return xyz[:, :, 0], xyz[:, :, 1], xyz[:, :, 2], ranges, azimuths

    def calculate_additional_metrics(self):
        """
        Triggers calculation of other metrics, such as ZDR calculation, textures etc.
        """
        self.calculate_differential_reflectivity()
        self.calculate_depolarization_ratio()

    def calculate_differential_reflectivity(self):
        """
        Calculates differential reflectivity or ZDR, defined as DBZH - DBZV (following Stepanian et al., 2016).
        """
        for elevation in self.scans:
            self.scans[elevation]['ZDR'] = 10 ** ((self.scans[elevation]['DBZH'] - self.scans[elevation]['DBZV'])/10)

    def calculate_depolarization_ratio(self):
        """
        Calculated depolarization ratio following Kilambi et al. (2018).

        DR = 10 * log10((ZDR + 1 - 2 * ZDR^0.5 * RHOHV) / (ZDR + 1 + 2 * ZDR^0.5 * RHOHV))
        """
        for elevation in self.scans:
            self.scans[elevation]['DR'] = 10 * np.log10((self.scans[elevation]['ZDR'] + 1 - 2 * np.sqrt(self.scans[elevation]['ZDR']) * self.scans[elevation]['RHOHV']) /
                                                        (self.scans[elevation]['ZDR'] + 1 + 2 * np.sqrt(self.scans[elevation]['ZDR']) * self.scans[elevation]['RHOHV']))

    def label_biology_using_depolarization_ratio(self, thresh=-12):
        """
        Following Kilambi et al. (2018) and labelling as biology anything above a depolarization ratio of -12 seems to
        work fairly well, so we'll use that, but threshold can be overridden.
        """
        for elevation in self.scans:
            self.scans[elevation]['biology'] = (self.scans[elevation]['DR'] > thresh) * 1

    def flatten_scans_to_pointcloud(self):
        """
        The function that 'builds' the pointcloud by flattening the self.scans dictionary into a single Pandas dataframe
        self.pointcloud. This is a necessary step to e.g. save the pointcloud in a CSV file for viewing in CloudCompare.
        """
        for elevation in self.scans:
            dataframe = self.scans[elevation].to_dataframe()
            dataframe['elevation'] = elevation
            dataframe.reset_index(inplace=True)

            if isinstance(self.pointcloud, pd.DataFrame):
                self.pointcloud = pd.concat([self.pointcloud, dataframe])
            else:
                self.pointcloud = dataframe

    def drop_na_rows(self, subset=None):
        """
        Drops rows from the file where columns in subset containg NA/NaN values. By default this is done for rows that
        contain no values for DBZH and VRADH.

        :param subset: Iterable of column names that cannot have NA/NaN values in rows.
        """
        if subset is None:
            subset = ['DBZH', 'VRADH']

        self.pointcloud.dropna(subset=subset, inplace=True)
        
    def drop_center_points(self):
        self.pointcloud.drop(self.pointcloud[(self.pointcloud['x'] == 0) & (self.pointcloud['y'] == 0)].index, inplace=True)

    def set_column_order(self):
        """
        Orders columns in order defined in self.column_order for both single-pol and dual-pol polarizations.
        """
        order = self.column_order[self.radar['polarization']]
        columns_unordered = list(self.pointcloud.columns)
        columns_ordered = [variable for variable in order if variable in columns_unordered]
        self.pointcloud = self.pointcloud[columns_ordered]
        self.pointcloud.set_index(['elevation', 'azimuth', 'range'], inplace=True)
        
    def remove_columns(self):
        newpc = self.pointcloud.copy()
        newpc = newpc[['x', 'y', 'z', 'DBZH', 'VRADH', 'biology']]
        self.pointcloud = newpc
        self.pointcloud.reset_index(drop=True, inplace=True)

    def to_csv(self, file_path, compression=None, float_format=None):
        """
        Exports the point cloud to a CSV file.
        :param file_path: path to CSV file. If the file does not exist yet, it will be created.
        """
        self.pointcloud.to_csv(file_path, na_rep="NaN", quotechar='"', index=False, compression=compression,
                               float_format=float_format)
        
    def to_parquet(self, file_path):
        """
        Exports the point cloud to a parquet file.
        :param file_path: path to parquet file. If the file does not exist yet, it will be created.
        """
        
        self.pointcloud.to_parquet(file_path)

    @property
    def elevations(self):
        return sorted(self._elevations)

    @elevations.setter
    def elevations(self, value):
        self._elevations.append(value)

    radar_metadata = {
        'DeBilt': {'altitude': 44, 'polarization': 'SinglePol'},
        'DenHelder': {'altitude': 51, 'polarization': 'DualPol'},
        'Herwijnen': {'altitude': 27.7, 'polarization': 'DualPol'}
    }

    excluded_scans = {'/scan1', '/scan7', '/scan16', '/dataset1', '/dataset7', '/dataset16'}

    available_datasets = {
        'SinglePol': {
            'uZ': {'description': 'Uncorrected reflectivity', 'ODIM': 'TH'},
            'V': {'description': 'Radial velocity', 'ODIM': 'VRADH'},
            'Z': {'description': 'Reflectivity (corrected)', 'ODIM': 'DBZH'},
            'W': {'description': 'Spectral width of radial velocity', 'ODIM': 'WRADH'},
            'TX_power': {'description': 'Total reflectivity factor', 'ODIM': None}
        },
        'DualPol': {
            'CCOR': {'description': 'Clutter correction (horizontally polarized)', 'ODIM': 'CCORH'},
            'CCORv': {'description': 'Clutter correction (vertically polarized)', 'ODIM': 'CCORV'},
            'CPA': {'description': 'Clutter phase alignment (horizontally polarized)', 'ODIM': 'CPAH'},
            'CPAv': {'description': 'Clutter phase alignment (vertically polarized)', 'ODIM': 'CPAV'},
            'KDP': {'description': 'Specific differential phase', 'ODIM': 'KDP'},
            'PhiDP': {'description': 'Differential phase', 'ODIM': 'PHIDP'},
            'RhoHV': {'description': 'Correlation between Z(h) and Zv', 'ODIM': 'RHOHV'},
            'SQI': {'description': 'Signal quality index (horizontally polarized)', 'ODIM': 'SQIH'},
            'SQIv': {'description': 'Signal quality index (vertically polarized)', 'ODIM': 'SQIV'},
            'TX_power': {'description': 'Total reflectivity factor', 'ODIM': None},
            'uPhiDP': {'description': 'Unsmoothed differential phase', 'ODIM': 'PHIDPU'},
            'uZ': {'description': 'Uncorrected reflectivity (horizontally polarized)', 'ODIM': 'TH'},
            'uZv': {'description': 'Uncorrected reflectivity (vertically polarized)', 'ODIM': 'TV'},
            'V': {'description': 'Radial velocity (horizontally polarized)', 'ODIM': 'VRADH'},
            'Vv': {'description': 'Radial velocity (vertically polarized)', 'ODIM': 'VRADV'},
            'W': {'description': 'Spectral width of radial velocity (horizontally polarized)', 'ODIM': 'WRADH'},
            'Wv': {'description': 'Spectral width of radial velocity (vertically polarized)', 'ODIM': 'WRADV'},
            'Z': {'description': 'Reflectivity (corrected, horizontally polarized)', 'ODIM': 'DBZH'},
            'Zv': {'description': 'Reflectivity (corrected, vertically polarized)', 'ODIM': 'DBZV'}
        }
    }

    excluded_datasets = {
        'SinglePol': {'CCOR', 'CCORv', 'CPA', 'CPAv', 'SQI', 'SQIv', 'TX_power',  # KNMI HDF5
                      'CCORH', 'CCORV', 'CPAH', 'CPAV', 'SQIH', 'SQIV'},  # ODIM HDF5
        'DualPol': {'CCOR', 'CCORv', 'CPA', 'CPAv', 'SQI', 'SQIv', 'TX_power',  # KNMI HDF5
                    'CCORH', 'CCORV', 'CPAH', 'CPAV', 'SQIH', 'SQIV'}  # ODIM HDF5
    }

    column_order = {
        'SinglePol': ['elevation', 'azimuth', 'range', 'x', 'y', 'z', 'DBZH', 'TH', 'VRADH', 'WRADH', 'TX_power'],
        'DualPol': ['elevation', 'azimuth', 'range', 'x', 'y', 'z', 'DBZH', 'DBZV', 'TH', 'TV', 'VRADH', 'VRADV',
                    'WRADH', 'WRADV', 'PHIDP', 'PHIDPU', 'RHOHV', 'KDP', 'ZDR', 'DR', 'CCORH', 'CCORV', 'CPAH', 'CPAV',
                    'SQIH', 'SQIV', 'TX_power', 'biology']
    }

# %%
def convert_folder(folder_name):
    filenames = os.listdir(f"../data/2021/10/{folder_name}")
    i = 1
    for file in filenames:
        print(f"Folder {folder_name} progression: {i}/{len(filenames)}")
        pc = BirdCloud()
        pc.from_odim_file(f"../data/2021/10/{folder_name}/{file}")
        new_name = file.split(".")[0]
        new_name = new_name + ".parquet"
        pc.to_parquet(f"../pointclouds/{new_name}")
        i += 1

# %%
ps = []
for i in ['09','10','11','12','13','14','15','16']:
    p = Thread(target=convert_folder, args=(i,))
    p.start()
# Out:
# Folder 12 progression: 1/287
# Folder 15 progression: 1/287Folder 11 progression: 1/282
#
# Folder 14 progression: 1/286
# Folder 13 progression: 1/286
# Folder 16 progression: 1/286
# Folder 09 progression: 1/288
# Folder 10 progression: 1/287
# Folder 14 progression: 2/286
# Folder 11 progression: 2/282
# Folder 12 progression: 2/287
# Folder 09 progression: 2/288
# Folder 10 progression: 2/287
# Folder 13 progression: 2/286
# Folder 15 progression: 2/287
# Folder 16 progression: 2/286
# Folder 10 progression: 3/287
# Folder 12 progression: 3/287
# Folder 11 progression: 3/282
# Folder 09 progression: 3/288
# Folder 15 progression: 3/287
# Folder 14 progression: 3/286
# Folder 16 progression: 3/286
# Folder 13 progression: 3/286
# Folder 10 progression: 4/287
# Folder 12 progression: 4/287
# Folder 11 progression: 4/282
# Folder 09 progression: 4/288
# Folder 15 progression: 4/287
# Folder 16 progression: 4/286
# Folder 14 progression: 4/286
# Folder 13 progression: 4/286
# Folder 10 progression: 5/287
# Folder 12 progression: 5/287
# Folder 11 progression: 5/282
# Folder 09 progression: 5/288
# Folder 15 progression: 5/287
# Folder 16 progression: 5/286
# Folder 14 progression: 5/286
# Folder 13 progression: 5/286
# Folder 10 progression: 6/287
# Folder 12 progression: 6/287
# Folder 09 progression: 6/288
# Folder 11 progression: 6/282
# Folder 16 progression: 6/286
# Folder 15 progression: 6/287
# Folder 14 progression: 6/286
# Folder 13 progression: 6/286
# Folder 10 progression: 7/287
# Folder 12 progression: 7/287
# Folder 09 progression: 7/288
# Folder 11 progression: 7/282
# Folder 16 progression: 7/286
# Folder 15 progression: 7/287
# Folder 13 progression: 7/286
# Folder 14 progression: 7/286
# Folder 10 progression: 8/287
# Folder 12 progression: 8/287
# Folder 09 progression: 8/288
# Folder 11 progression: 8/282
# Folder 16 progression: 8/286
# Folder 15 progression: 8/287
# Folder 14 progression: 8/286
# Folder 13 progression: 8/286
# Folder 10 progression: 9/287
# Folder 12 progression: 9/287
# Folder 09 progression: 9/288
# Folder 11 progression: 9/282
# Folder 16 progression: 9/286
# Folder 15 progression: 9/287
# Folder 13 progression: 9/286
# Folder 14 progression: 9/286
# Folder 10 progression: 10/287
# Folder 12 progression: 10/287
# Folder 09 progression: 10/288
# Folder 11 progression: 10/282
# Folder 16 progression: 10/286
# Folder 15 progression: 10/287
# Folder 13 progression: 10/286
# Folder 14 progression: 10/286
# Folder 10 progression: 11/287
# Folder 12 progression: 11/287
# Folder 09 progression: 11/288
# Folder 11 progression: 11/282
# Folder 16 progression: 11/286
# Folder 15 progression: 11/287
# Folder 13 progression: 11/286
# Folder 14 progression: 11/286
# Folder 10 progression: 12/287
# Folder 12 progression: 12/287
# Folder 09 progression: 12/288
# Folder 11 progression: 12/282
# Folder 16 progression: 12/286
# Folder 15 progression: 12/287
# Folder 13 progression: 12/286
# Folder 14 progression: 12/286
# Folder 10 progression: 13/287
# Folder 12 progression: 13/287
# Folder 09 progression: 13/288
# Folder 11 progression: 13/282
# Folder 16 progression: 13/286
# Folder 15 progression: 13/287
# Folder 13 progression: 13/286
# Folder 14 progression: 13/286
# Folder 10 progression: 14/287
# Folder 12 progression: 14/287
# Folder 09 progression: 14/288
# Folder 11 progression: 14/282
# Folder 16 progression: 14/286
# Folder 15 progression: 14/287
# Folder 13 progression: 14/286
# Folder 14 progression: 14/286
# Folder 10 progression: 15/287
# Folder 12 progression: 15/287
# Folder 09 progression: 15/288
# Folder 11 progression: 15/282
# Folder 16 progression: 15/286
# Folder 15 progression: 15/287
# Folder 13 progression: 15/286
# Folder 14 progression: 15/286
# Folder 10 progression: 16/287
# Folder 12 progression: 16/287
# Folder 09 progression: 16/288
# Folder 11 progression: 16/282
# Folder 16 progression: 16/286
# Folder 15 progression: 16/287
# Folder 13 progression: 16/286
# Folder 14 progression: 16/286
# Folder 10 progression: 17/287
# Folder 12 progression: 17/287
# Folder 09 progression: 17/288
# Folder 11 progression: 17/282
# Folder 16 progression: 17/286
# Folder 15 progression: 17/287
# Folder 13 progression: 17/286
# Folder 14 progression: 17/286
# Folder 10 progression: 18/287
# Folder 12 progression: 18/287
# Folder 09 progression: 18/288
# Folder 11 progression: 18/282
# Folder 16 progression: 18/286
# Folder 15 progression: 18/287
# Folder 13 progression: 18/286
# Folder 14 progression: 18/286
# Folder 10 progression: 19/287
# Folder 12 progression: 19/287
# Folder 09 progression: 19/288
# Folder 11 progression: 19/282
# Folder 16 progression: 19/286
# Folder 15 progression: 19/287
# Folder 13 progression: 19/286
# Folder 14 progression: 19/286
# Folder 10 progression: 20/287
# Folder 12 progression: 20/287
# Folder 09 progression: 20/288
# Folder 11 progression: 20/282
# Folder 16 progression: 20/286
# Folder 15 progression: 20/287
# Folder 13 progression: 20/286
# Folder 14 progression: 20/286
# Folder 10 progression: 21/287
# Folder 12 progression: 21/287
# Folder 09 progression: 21/288
# Folder 11 progression: 21/282
# Folder 15 progression: 21/287
# Folder 16 progression: 21/286
# Folder 13 progression: 21/286
# Folder 14 progression: 21/286
# Folder 10 progression: 22/287
# Folder 12 progression: 22/287
# Folder 09 progression: 22/288
# Folder 11 progression: 22/282
# Folder 15 progression: 22/287
# Folder 16 progression: 22/286
# Folder 13 progression: 22/286
# Folder 14 progression: 22/286
# Folder 10 progression: 23/287
# Folder 12 progression: 23/287
# Folder 09 progression: 23/288
# Folder 11 progression: 23/282
# Folder 16 progression: 23/286
# Folder 15 progression: 23/287
# Folder 13 progression: 23/286
# Folder 14 progression: 23/286
# Folder 10 progression: 24/287
# Folder 12 progression: 24/287
# Folder 09 progression: 24/288
# Folder 11 progression: 24/282
# Folder 15 progression: 24/287
# Folder 16 progression: 24/286
# Folder 14 progression: 24/286
# Folder 13 progression: 24/286
# Folder 10 progression: 25/287
# Folder 12 progression: 25/287
# Folder 09 progression: 25/288
# Folder 11 progression: 25/282
# Folder 15 progression: 25/287
# Folder 16 progression: 25/286
# Folder 14 progression: 25/286
# Folder 13 progression: 25/286
# Folder 10 progression: 26/287
# Folder 12 progression: 26/287
# Folder 09 progression: 26/288
# Folder 11 progression: 26/282
# Folder 16 progression: 26/286
# Folder 15 progression: 26/287
# Folder 14 progression: 26/286
# Folder 13 progression: 26/286
# Folder 10 progression: 27/287
# Folder 12 progression: 27/287
# Folder 09 progression: 27/288
# Folder 11 progression: 27/282
# Folder 16 progression: 27/286
# Folder 15 progression: 27/287
# Folder 14 progression: 27/286
# Folder 13 progression: 27/286
# Folder 10 progression: 28/287
# Folder 12 progression: 28/287
# Folder 09 progression: 28/288
# Folder 11 progression: 28/282
# Folder 16 progression: 28/286
# Folder 15 progression: 28/287
# Folder 14 progression: 28/286
# Folder 13 progression: 28/286
# Folder 10 progression: 29/287
# Folder 12 progression: 29/287
# Folder 09 progression: 29/288
# Folder 11 progression: 29/282
# Folder 16 progression: 29/286
# Folder 15 progression: 29/287
# Folder 14 progression: 29/286
# Folder 13 progression: 29/286
# Folder 10 progression: 30/287
# Folder 12 progression: 30/287
# Folder 09 progression: 30/288
# Folder 11 progression: 30/282
# Folder 16 progression: 30/286
# Folder 15 progression: 30/287
# Folder 14 progression: 30/286
# Folder 13 progression: 30/286
# Folder 10 progression: 31/287
# Folder 09 progression: 31/288
# Folder 12 progression: 31/287
# Folder 11 progression: 31/282
# Folder 16 progression: 31/286
# Folder 15 progression: 31/287
# Folder 14 progression: 31/286
# Folder 13 progression: 31/286
# Folder 10 progression: 32/287
# Folder 09 progression: 32/288
# Folder 12 progression: 32/287
# Folder 11 progression: 32/282
# Folder 16 progression: 32/286
# Folder 15 progression: 32/287
# Folder 14 progression: 32/286
# Folder 13 progression: 32/286
# Folder 10 progression: 33/287
# Folder 09 progression: 33/288
# Folder 12 progression: 33/287
# Folder 11 progression: 33/282
# Folder 16 progression: 33/286
# Folder 15 progression: 33/287
# Folder 14 progression: 33/286
# Folder 13 progression: 33/286
# Folder 10 progression: 34/287
# Folder 09 progression: 34/288
# Folder 12 progression: 34/287
# Folder 11 progression: 34/282
# Folder 16 progression: 34/286
# Folder 15 progression: 34/287
# Folder 14 progression: 34/286
# Folder 13 progression: 34/286
# Folder 10 progression: 35/287
# Folder 09 progression: 35/288
# Folder 12 progression: 35/287
# Folder 11 progression: 35/282
# Folder 16 progression: 35/286
# Folder 15 progression: 35/287
# Folder 14 progression: 35/286
# Folder 13 progression: 35/286
# Folder 10 progression: 36/287
# Folder 09 progression: 36/288
# Folder 12 progression: 36/287
# Folder 11 progression: 36/282
# Folder 16 progression: 36/286
# Folder 15 progression: 36/287
# Folder 14 progression: 36/286
# Folder 13 progression: 36/286
# Folder 10 progression: 37/287
# Folder 09 progression: 37/288
# Folder 11 progression: 37/282
# Folder 12 progression: 37/287
# Folder 16 progression: 37/286
# Folder 15 progression: 37/287
# Folder 14 progression: 37/286
# Folder 13 progression: 37/286
# Folder 10 progression: 38/287
# Folder 09 progression: 38/288
# Folder 11 progression: 38/282
# Folder 12 progression: 38/287
# Folder 16 progression: 38/286
# Folder 15 progression: 38/287
# Folder 14 progression: 38/286
# Folder 13 progression: 38/286
# Folder 10 progression: 39/287
# Folder 09 progression: 39/288
# Folder 11 progression: 39/282
# Folder 16 progression: 39/286
# Folder 12 progression: 39/287
# Folder 15 progression: 39/287
# Folder 14 progression: 39/286
# Folder 13 progression: 39/286
# Folder 10 progression: 40/287
# Folder 09 progression: 40/288
# Folder 11 progression: 40/282
# Folder 16 progression: 40/286
# Folder 12 progression: 40/287
# Folder 15 progression: 40/287
# Folder 14 progression: 40/286
# Folder 13 progression: 40/286
# Folder 10 progression: 41/287
# Folder 09 progression: 41/288
# Folder 11 progression: 41/282
# Folder 16 progression: 41/286
# Folder 12 progression: 41/287
# Folder 15 progression: 41/287
# Folder 14 progression: 41/286
# Folder 13 progression: 41/286
# Folder 10 progression: 42/287
# Folder 09 progression: 42/288
# Folder 11 progression: 42/282
# Folder 16 progression: 42/286
# Folder 12 progression: 42/287
# Folder 15 progression: 42/287
# Folder 14 progression: 42/286
# Folder 13 progression: 42/286
# Folder 10 progression: 43/287
# Folder 09 progression: 43/288
# Folder 11 progression: 43/282
# Folder 16 progression: 43/286
# Folder 12 progression: 43/287
# Folder 15 progression: 43/287
# Folder 14 progression: 43/286
# Folder 13 progression: 43/286
# Folder 10 progression: 44/287
# Folder 09 progression: 44/288
# Folder 11 progression: 44/282
# Folder 16 progression: 44/286
# Folder 12 progression: 44/287
# Folder 15 progression: 44/287
# Folder 14 progression: 44/286
# Folder 13 progression: 44/286
# Folder 10 progression: 45/287
# Folder 09 progression: 45/288
# Folder 11 progression: 45/282
# Folder 16 progression: 45/286
# Folder 12 progression: 45/287
# Folder 15 progression: 45/287
# Folder 14 progression: 45/286
# Folder 13 progression: 45/286
# Folder 10 progression: 46/287
# Folder 09 progression: 46/288
# Folder 11 progression: 46/282
# Folder 16 progression: 46/286
# Folder 12 progression: 46/287
# Folder 15 progression: 46/287
# Folder 14 progression: 46/286
# Folder 13 progression: 46/286
# Folder 10 progression: 47/287
# Folder 09 progression: 47/288
# Folder 11 progression: 47/282
# Folder 16 progression: 47/286
# Folder 12 progression: 47/287
# Folder 15 progression: 47/287
# Folder 14 progression: 47/286
# Folder 13 progression: 47/286
# Folder 10 progression: 48/287
# Folder 09 progression: 48/288
# Folder 11 progression: 48/282
# Folder 16 progression: 48/286
# Folder 12 progression: 48/287
# Folder 15 progression: 48/287
# Folder 14 progression: 48/286
# Folder 13 progression: 48/286
# Folder 10 progression: 49/287
# Folder 09 progression: 49/288
# Folder 11 progression: 49/282
# Folder 16 progression: 49/286
# Folder 12 progression: 49/287
# Folder 15 progression: 49/287
# Folder 14 progression: 49/286
# Folder 13 progression: 49/286
# Folder 10 progression: 50/287
# Folder 09 progression: 50/288
# Folder 11 progression: 50/282
# Folder 16 progression: 50/286
# Folder 12 progression: 50/287
# Folder 15 progression: 50/287
# Folder 14 progression: 50/286
# Folder 13 progression: 50/286
# Folder 10 progression: 51/287
# Folder 09 progression: 51/288
# Folder 11 progression: 51/282
# Folder 16 progression: 51/286
# Folder 12 progression: 51/287
# Folder 15 progression: 51/287
# Folder 14 progression: 51/286
# Folder 13 progression: 51/286
# Folder 10 progression: 52/287
# Folder 09 progression: 52/288
# Folder 11 progression: 52/282
# Folder 16 progression: 52/286
# Folder 12 progression: 52/287
# Folder 15 progression: 52/287
# Folder 14 progression: 52/286
# Folder 13 progression: 52/286
# Folder 10 progression: 53/287
# Folder 09 progression: 53/288
# Folder 11 progression: 53/282
# Folder 16 progression: 53/286
# Folder 12 progression: 53/287
# Folder 15 progression: 53/287
# Folder 14 progression: 53/286
# Folder 13 progression: 53/286
# Folder 10 progression: 54/287
# Folder 09 progression: 54/288
# Folder 11 progression: 54/282
# Folder 16 progression: 54/286
# Folder 12 progression: 54/287
# Folder 15 progression: 54/287
# Folder 14 progression: 54/286
# Folder 13 progression: 54/286
# Folder 10 progression: 55/287
# Folder 09 progression: 55/288
# Folder 11 progression: 55/282
# Folder 16 progression: 55/286
# Folder 12 progression: 55/287
# Folder 15 progression: 55/287
# Folder 14 progression: 55/286
# Folder 13 progression: 55/286
# Folder 10 progression: 56/287
# Folder 09 progression: 56/288
# Folder 11 progression: 56/282
# Folder 16 progression: 56/286
# Folder 12 progression: 56/287
# Folder 15 progression: 56/287
# Folder 14 progression: 56/286
# Folder 13 progression: 56/286
# Folder 10 progression: 57/287
# Folder 09 progression: 57/288
# Folder 11 progression: 57/282
# Folder 16 progression: 57/286
# Folder 12 progression: 57/287
# Folder 15 progression: 57/287
# Folder 14 progression: 57/286
# Folder 13 progression: 57/286
# Folder 10 progression: 58/287
# Folder 09 progression: 58/288
# Folder 11 progression: 58/282
# Folder 16 progression: 58/286
# Folder 12 progression: 58/287
# Folder 15 progression: 58/287
# Folder 14 progression: 58/286
# Folder 13 progression: 58/286
# Folder 10 progression: 59/287
# Folder 09 progression: 59/288
# Folder 11 progression: 59/282
# Folder 16 progression: 59/286
# Folder 12 progression: 59/287
# Folder 15 progression: 59/287
# Folder 14 progression: 59/286
# Folder 13 progression: 59/286
# Folder 10 progression: 60/287
# Folder 09 progression: 60/288
# Folder 11 progression: 60/282
# Folder 16 progression: 60/286
# Folder 12 progression: 60/287
# Folder 14 progression: 60/286
# Folder 15 progression: 60/287
# Folder 13 progression: 60/286
# Folder 10 progression: 61/287
# Folder 09 progression: 61/288
# Folder 11 progression: 61/282
# Folder 16 progression: 61/286
# Folder 12 progression: 61/287
# Folder 14 progression: 61/286
# Folder 15 progression: 61/287
# Folder 13 progression: 61/286
# Folder 10 progression: 62/287
# Folder 09 progression: 62/288
# Folder 11 progression: 62/282
# Folder 16 progression: 62/286
# Folder 12 progression: 62/287
# Folder 14 progression: 62/286
# Folder 15 progression: 62/287
# Folder 13 progression: 62/286
# Folder 10 progression: 63/287
# Folder 09 progression: 63/288
# Folder 11 progression: 63/282
# Folder 16 progression: 63/286
# Folder 12 progression: 63/287
# Folder 14 progression: 63/286
# Folder 15 progression: 63/287
# Folder 13 progression: 63/286
# Folder 10 progression: 64/287
# Folder 09 progression: 64/288
# Folder 11 progression: 64/282
# Folder 16 progression: 64/286
# Folder 12 progression: 64/287
# Folder 14 progression: 64/286
# Folder 15 progression: 64/287
# Folder 13 progression: 64/286
# Folder 10 progression: 65/287
# Folder 09 progression: 65/288
# Folder 11 progression: 65/282
# Folder 16 progression: 65/286
# Folder 12 progression: 65/287
# Folder 14 progression: 65/286
# Folder 15 progression: 65/287
# Folder 13 progression: 65/286
# Folder 10 progression: 66/287
# Folder 09 progression: 66/288
# Folder 11 progression: 66/282
# Folder 16 progression: 66/286
# Folder 12 progression: 66/287
# Folder 14 progression: 66/286
# Folder 15 progression: 66/287
# Folder 13 progression: 66/286
# Folder 10 progression: 67/287
# Folder 09 progression: 67/288
# Folder 11 progression: 67/282
# Folder 16 progression: 67/286
# Folder 12 progression: 67/287
# Folder 14 progression: 67/286
# Folder 15 progression: 67/287
# Folder 13 progression: 67/286
# Folder 10 progression: 68/287
# Folder 09 progression: 68/288
# Folder 11 progression: 68/282
# Folder 16 progression: 68/286
# Folder 12 progression: 68/287
# Folder 14 progression: 68/286
# Folder 15 progression: 68/287
# Folder 13 progression: 68/286
# Folder 10 progression: 69/287
# Folder 09 progression: 69/288
# Folder 11 progression: 69/282
# Folder 16 progression: 69/286
# Folder 12 progression: 69/287
# Folder 14 progression: 69/286
# Folder 15 progression: 69/287
# Folder 13 progression: 69/286
# Folder 10 progression: 70/287
# Folder 09 progression: 70/288
# Folder 11 progression: 70/282
# Folder 16 progression: 70/286
# Folder 12 progression: 70/287
# Folder 14 progression: 70/286
# Folder 15 progression: 70/287
# Folder 13 progression: 70/286
# Folder 10 progression: 71/287
# Folder 09 progression: 71/288
# Folder 11 progression: 71/282
# Folder 16 progression: 71/286
# Folder 12 progression: 71/287
# Folder 14 progression: 71/286
# Folder 13 progression: 71/286
# Folder 15 progression: 71/287
# Folder 10 progression: 72/287
# Folder 09 progression: 72/288
# Folder 11 progression: 72/282
# Folder 16 progression: 72/286
# Folder 12 progression: 72/287
# Folder 14 progression: 72/286
# Folder 13 progression: 72/286
# Folder 15 progression: 72/287
# Folder 10 progression: 73/287
# Folder 09 progression: 73/288
# Folder 11 progression: 73/282
# Folder 16 progression: 73/286
# Folder 12 progression: 73/287
# Folder 14 progression: 73/286
# Folder 13 progression: 73/286
# Folder 15 progression: 73/287
# Folder 10 progression: 74/287
# Folder 09 progression: 74/288
# Folder 11 progression: 74/282
# Folder 16 progression: 74/286
# Folder 12 progression: 74/287
# Folder 14 progression: 74/286
# Folder 13 progression: 74/286
# Folder 15 progression: 74/287
# Folder 10 progression: 75/287
# Folder 09 progression: 75/288
# Folder 11 progression: 75/282
# Folder 16 progression: 75/286
# Folder 12 progression: 75/287
# Folder 14 progression: 75/286
# Folder 13 progression: 75/286
# Folder 15 progression: 75/287
# Folder 10 progression: 76/287
# Folder 09 progression: 76/288
# Folder 11 progression: 76/282
# Folder 16 progression: 76/286
# Folder 12 progression: 76/287
# Folder 14 progression: 76/286
# Folder 13 progression: 76/286
# Folder 15 progression: 76/287
# Folder 10 progression: 77/287
# Folder 09 progression: 77/288
# Folder 11 progression: 77/282
# Folder 16 progression: 77/286
# Folder 12 progression: 77/287
# Folder 14 progression: 77/286
# Folder 13 progression: 77/286
# Folder 15 progression: 77/287
# Folder 10 progression: 78/287
# Folder 09 progression: 78/288
# Folder 11 progression: 78/282
# Folder 16 progression: 78/286
# Folder 12 progression: 78/287
# Folder 14 progression: 78/286
# Folder 13 progression: 78/286
# Folder 10 progression: 79/287
# Folder 15 progression: 78/287
# Folder 09 progression: 79/288
# Folder 11 progression: 79/282
# Folder 16 progression: 79/286
# Folder 12 progression: 79/287
# Folder 14 progression: 79/286
# Folder 13 progression: 79/286
# Folder 10 progression: 80/287
# Folder 15 progression: 79/287
# Folder 09 progression: 80/288
# Folder 11 progression: 80/282
# Folder 16 progression: 80/286
# Folder 12 progression: 80/287
# Folder 14 progression: 80/286
# Folder 13 progression: 80/286
# Folder 10 progression: 81/287
# Folder 15 progression: 80/287
# Folder 09 progression: 81/288
# Folder 11 progression: 81/282
# Folder 16 progression: 81/286
# Folder 12 progression: 81/287
# Folder 14 progression: 81/286
# Folder 13 progression: 81/286
# Folder 10 progression: 82/287
# Folder 15 progression: 81/287
# Folder 09 progression: 82/288
# Folder 11 progression: 82/282
# Folder 16 progression: 82/286
# Folder 12 progression: 82/287
# Folder 14 progression: 82/286
# Folder 13 progression: 82/286
# Folder 10 progression: 83/287
# Folder 15 progression: 82/287
# Folder 09 progression: 83/288
# Folder 11 progression: 83/282
# Folder 16 progression: 83/286
# Folder 12 progression: 83/287
# Folder 14 progression: 83/286
# Folder 13 progression: 83/286
# Folder 10 progression: 84/287
# Folder 15 progression: 83/287
# Folder 09 progression: 84/288
# Folder 11 progression: 84/282
# Folder 16 progression: 84/286
# Folder 12 progression: 84/287
# Folder 14 progression: 84/286
# Folder 13 progression: 84/286
# Folder 10 progression: 85/287
# Folder 09 progression: 85/288
# Folder 15 progression: 84/287
# Folder 11 progression: 85/282
# Folder 16 progression: 85/286
# Folder 12 progression: 85/287
# Folder 14 progression: 85/286
# Folder 13 progression: 85/286
# Folder 10 progression: 86/287
# Folder 09 progression: 86/288
# Folder 15 progression: 85/287
# Folder 11 progression: 86/282
# Folder 16 progression: 86/286
# Folder 12 progression: 86/287
# Folder 14 progression: 86/286
# Folder 13 progression: 86/286
# Folder 10 progression: 87/287
# Folder 09 progression: 87/288
# Folder 15 progression: 86/287
# Folder 11 progression: 87/282
# Folder 16 progression: 87/286
# Folder 12 progression: 87/287
# Folder 14 progression: 87/286
# Folder 13 progression: 87/286
# Folder 10 progression: 88/287
# Folder 09 progression: 88/288
# Folder 15 progression: 87/287
# Folder 11 progression: 88/282
# Folder 16 progression: 88/286
# Folder 14 progression: 88/286
# Folder 12 progression: 88/287
# Folder 13 progression: 88/286
# Folder 10 progression: 89/287
# Folder 09 progression: 89/288
# Folder 15 progression: 88/287
# Folder 11 progression: 89/282
# Folder 16 progression: 89/286
# Folder 14 progression: 89/286
# Folder 12 progression: 89/287
# Folder 13 progression: 89/286
# Folder 10 progression: 90/287
# Folder 09 progression: 90/288
# Folder 15 progression: 89/287
# Folder 11 progression: 90/282
# Folder 16 progression: 90/286
# Folder 14 progression: 90/286
# Folder 12 progression: 90/287
# Folder 13 progression: 90/286
# Folder 10 progression: 91/287
# Folder 09 progression: 91/288
# Folder 15 progression: 90/287
# Folder 11 progression: 91/282
# Folder 16 progression: 91/286
# Folder 14 progression: 91/286
# Folder 12 progression: 91/287
# Folder 13 progression: 91/286
# Folder 10 progression: 92/287
# Folder 09 progression: 92/288
# Folder 15 progression: 91/287
# Folder 11 progression: 92/282
# Folder 16 progression: 92/286
# Folder 14 progression: 92/286
# Folder 12 progression: 92/287
# Folder 13 progression: 92/286
# Folder 10 progression: 93/287
# Folder 09 progression: 93/288
# Folder 15 progression: 92/287
# Folder 11 progression: 93/282
# Folder 16 progression: 93/286
# Folder 14 progression: 93/286
# Folder 12 progression: 93/287
# Folder 13 progression: 93/286
# Folder 10 progression: 94/287
# Folder 09 progression: 94/288
# Folder 15 progression: 93/287
# Folder 11 progression: 94/282
# Folder 16 progression: 94/286
# Folder 14 progression: 94/286
# Folder 12 progression: 94/287
# Folder 13 progression: 94/286
# Folder 10 progression: 95/287
# Folder 09 progression: 95/288
# Folder 15 progression: 94/287
# Folder 11 progression: 95/282
# Folder 16 progression: 95/286
# Folder 14 progression: 95/286
# Folder 12 progression: 95/287
# Folder 13 progression: 95/286
# Folder 10 progression: 96/287
# Folder 09 progression: 96/288
# Folder 11 progression: 96/282
# Folder 15 progression: 95/287
# Folder 16 progression: 96/286
# Folder 14 progression: 96/286
# Folder 12 progression: 96/287
# Folder 13 progression: 96/286
# Folder 10 progression: 97/287
# Folder 09 progression: 97/288
# Folder 11 progression: 97/282
# Folder 15 progression: 96/287
# Folder 16 progression: 97/286
# Folder 14 progression: 97/286
# Folder 12 progression: 97/287
# Folder 13 progression: 97/286
# Folder 10 progression: 98/287
# Folder 09 progression: 98/288
# Folder 11 progression: 98/282
# Folder 15 progression: 97/287
# Folder 16 progression: 98/286
# Folder 14 progression: 98/286
# Folder 12 progression: 98/287
# Folder 13 progression: 98/286
# Folder 10 progression: 99/287
# Folder 09 progression: 99/288
# Folder 11 progression: 99/282
# Folder 15 progression: 98/287
# Folder 16 progression: 99/286
# Folder 14 progression: 99/286
# Folder 12 progression: 99/287
# Folder 13 progression: 99/286
# Folder 10 progression: 100/287
# Folder 09 progression: 100/288
# Folder 11 progression: 100/282
# Folder 15 progression: 99/287
# Folder 16 progression: 100/286
# Folder 14 progression: 100/286
# Folder 12 progression: 100/287
# Folder 13 progression: 100/286
# Folder 10 progression: 101/287
# Folder 09 progression: 101/288
# Folder 11 progression: 101/282
# Folder 15 progression: 100/287
# Folder 16 progression: 101/286
# Folder 14 progression: 101/286
# Folder 12 progression: 101/287
# Folder 13 progression: 101/286
# Folder 10 progression: 102/287
# Folder 09 progression: 102/288
# Folder 11 progression: 102/282
# Folder 15 progression: 101/287
# Folder 16 progression: 102/286
# Folder 14 progression: 102/286
# Folder 12 progression: 102/287
# Folder 13 progression: 102/286
# Folder 10 progression: 103/287
# Folder 09 progression: 103/288
# Folder 11 progression: 103/282
# Folder 15 progression: 102/287
# Folder 16 progression: 103/286
# Folder 14 progression: 103/286
# Folder 12 progression: 103/287
# Folder 13 progression: 103/286
# Folder 10 progression: 104/287
# Folder 09 progression: 104/288
# Folder 11 progression: 104/282
# Folder 16 progression: 104/286
# Folder 15 progression: 103/287
# Folder 14 progression: 104/286
# Folder 12 progression: 104/287
# Folder 13 progression: 104/286
# Folder 10 progression: 105/287
# Folder 09 progression: 105/288
# Folder 11 progression: 105/282
# Folder 16 progression: 105/286
# Folder 15 progression: 104/287
# Folder 14 progression: 105/286
# Folder 12 progression: 105/287
# Folder 13 progression: 105/286
# Folder 10 progression: 106/287
# Folder 09 progression: 106/288
# Folder 11 progression: 106/282
# Folder 16 progression: 106/286
# Folder 15 progression: 105/287
# Folder 14 progression: 106/286
# Folder 12 progression: 106/287
# Folder 13 progression: 106/286
# Folder 10 progression: 107/287
# Folder 09 progression: 107/288
# Folder 11 progression: 107/282
# Folder 16 progression: 107/286
# Folder 15 progression: 106/287
# Folder 14 progression: 107/286
# Folder 12 progression: 107/287
# Folder 13 progression: 107/286
# Folder 10 progression: 108/287
# Folder 09 progression: 108/288
# Folder 11 progression: 108/282
# Folder 16 progression: 108/286
# Folder 15 progression: 107/287
# Folder 14 progression: 108/286
# Folder 12 progression: 108/287
# Folder 13 progression: 108/286
# Folder 10 progression: 109/287
# Folder 09 progression: 109/288
# Folder 11 progression: 109/282
# Folder 16 progression: 109/286
# Folder 15 progression: 108/287
# Folder 14 progression: 109/286
# Folder 12 progression: 109/287
# Folder 13 progression: 109/286
# Folder 10 progression: 110/287
# Folder 09 progression: 110/288
# Folder 11 progression: 110/282
# Folder 16 progression: 110/286
# Folder 15 progression: 109/287
# Folder 14 progression: 110/286
# Folder 12 progression: 110/287
# Folder 13 progression: 110/286
# Folder 10 progression: 111/287
# Folder 09 progression: 111/288
# Folder 11 progression: 111/282
# Folder 16 progression: 111/286
# Folder 15 progression: 110/287
# Folder 14 progression: 111/286
# Folder 12 progression: 111/287
# Folder 13 progression: 111/286
# Folder 10 progression: 112/287
# Folder 09 progression: 112/288
# Folder 16 progression: 112/286
# Folder 11 progression: 112/282
# Folder 15 progression: 111/287
# Folder 14 progression: 112/286
# Folder 12 progression: 112/287
# Folder 13 progression: 112/286
# Folder 10 progression: 113/287
# Folder 09 progression: 113/288
# Folder 16 progression: 113/286
# Folder 11 progression: 113/282
# Folder 15 progression: 112/287
# Folder 14 progression: 113/286
# Folder 12 progression: 113/287
# Folder 13 progression: 113/286
# Folder 10 progression: 114/287
# Folder 09 progression: 114/288
# Folder 16 progression: 114/286
# Folder 11 progression: 114/282
# Folder 15 progression: 113/287
# Folder 14 progression: 114/286
# Folder 12 progression: 114/287
# Folder 13 progression: 114/286
# Folder 10 progression: 115/287
# Folder 09 progression: 115/288
# Folder 16 progression: 115/286
# Folder 11 progression: 115/282
# Folder 15 progression: 114/287
# Folder 14 progression: 115/286
# Folder 12 progression: 115/287
# Folder 13 progression: 115/286
# Folder 10 progression: 116/287
# Folder 09 progression: 116/288
# Folder 16 progression: 116/286
# Folder 11 progression: 116/282
# Folder 15 progression: 115/287
# Folder 14 progression: 116/286
# Folder 12 progression: 116/287
# Folder 13 progression: 116/286
# Folder 10 progression: 117/287
# Folder 09 progression: 117/288
# Folder 16 progression: 117/286
# Folder 11 progression: 117/282
# Folder 15 progression: 116/287
# Folder 14 progression: 117/286
# Folder 12 progression: 117/287
# Folder 13 progression: 117/286
# Folder 10 progression: 118/287
# Folder 09 progression: 118/288
# Folder 16 progression: 118/286
# Folder 11 progression: 118/282
# Folder 15 progression: 117/287
# Folder 14 progression: 118/286
# Folder 13 progression: 118/286
# Folder 12 progression: 118/287
# Folder 10 progression: 119/287
# Folder 09 progression: 119/288
# Folder 16 progression: 119/286
# Folder 11 progression: 119/282
# Folder 15 progression: 118/287
# Folder 14 progression: 119/286
# Folder 13 progression: 119/286
# Folder 12 progression: 119/287
# Folder 10 progression: 120/287
# Folder 09 progression: 120/288
# Folder 16 progression: 120/286
# Folder 11 progression: 120/282
# Folder 14 progression: 120/286
# Folder 15 progression: 119/287
# Folder 13 progression: 120/286
# Folder 12 progression: 120/287
# Folder 10 progression: 121/287
# Folder 09 progression: 121/288
# Folder 16 progression: 121/286
# Folder 11 progression: 121/282
# Folder 14 progression: 121/286
# Folder 15 progression: 120/287
# Folder 13 progression: 121/286
# Folder 12 progression: 121/287
# Folder 10 progression: 122/287
# Folder 09 progression: 122/288
# Folder 16 progression: 122/286
# Folder 11 progression: 122/282
# Folder 14 progression: 122/286
# Folder 15 progression: 121/287
# Folder 13 progression: 122/286
# Folder 12 progression: 122/287
# Folder 10 progression: 123/287
# Folder 09 progression: 123/288
# Folder 16 progression: 123/286
# Folder 11 progression: 123/282
# Folder 14 progression: 123/286
# Folder 15 progression: 122/287
# Folder 13 progression: 123/286
# Folder 12 progression: 123/287
# Folder 10 progression: 124/287
# Folder 09 progression: 124/288
# Folder 16 progression: 124/286
# Folder 11 progression: 124/282
# Folder 14 progression: 124/286
# Folder 15 progression: 123/287
# Folder 13 progression: 124/286
# Folder 12 progression: 124/287
# Folder 10 progression: 125/287
# Folder 09 progression: 125/288
# Folder 16 progression: 125/286
# Folder 11 progression: 125/282
# Folder 14 progression: 125/286
# Folder 15 progression: 124/287
# Folder 13 progression: 125/286
# Folder 10 progression: 126/287
# Folder 12 progression: 125/287
# Folder 09 progression: 126/288
# Folder 16 progression: 126/286
# Folder 11 progression: 126/282
# Folder 14 progression: 126/286
# Folder 15 progression: 125/287
# Folder 13 progression: 126/286
# Folder 10 progression: 127/287
# Folder 12 progression: 126/287
# Folder 09 progression: 127/288
# Folder 16 progression: 127/286
# Folder 11 progression: 127/282
# Folder 14 progression: 127/286
# Folder 15 progression: 126/287
# Folder 13 progression: 127/286
# Folder 10 progression: 128/287
# Folder 12 progression: 127/287
# Folder 09 progression: 128/288
# Folder 16 progression: 128/286
# Folder 11 progression: 128/282
# Folder 14 progression: 128/286
# Folder 15 progression: 127/287
# Folder 13 progression: 128/286
# Folder 10 progression: 129/287
# Folder 12 progression: 128/287
# Folder 09 progression: 129/288
# Folder 16 progression: 129/286
# Folder 11 progression: 129/282
# Folder 14 progression: 129/286
# Folder 15 progression: 128/287
# Folder 13 progression: 129/286
# Folder 10 progression: 130/287
# Folder 12 progression: 129/287
# Folder 09 progression: 130/288
# Folder 16 progression: 130/286
# Folder 11 progression: 130/282
# Folder 14 progression: 130/286
# Folder 15 progression: 129/287
# Folder 13 progression: 130/286
# Folder 10 progression: 131/287
# Folder 12 progression: 130/287
# Folder 09 progression: 131/288
# Folder 16 progression: 131/286
# Folder 11 progression: 131/282
# Folder 14 progression: 131/286
# Folder 15 progression: 130/287
# Folder 13 progression: 131/286
# Folder 10 progression: 132/287
# Folder 12 progression: 131/287
# Folder 09 progression: 132/288
# Folder 16 progression: 132/286
# Folder 11 progression: 132/282
# Folder 14 progression: 132/286
# Folder 15 progression: 131/287
# Folder 13 progression: 132/286
# Folder 10 progression: 133/287
# Folder 12 progression: 132/287
# Folder 09 progression: 133/288
# Folder 16 progression: 133/286
# Folder 11 progression: 133/282
# Folder 14 progression: 133/286
# Folder 15 progression: 132/287
# Folder 13 progression: 133/286
# Folder 10 progression: 134/287
# Folder 09 progression: 134/288
# Folder 12 progression: 133/287
# Folder 16 progression: 134/286
# Folder 11 progression: 134/282
# Folder 14 progression: 134/286
# Folder 15 progression: 133/287
# Folder 13 progression: 134/286
# Folder 10 progression: 135/287
# Folder 09 progression: 135/288
# Folder 12 progression: 134/287
# Folder 16 progression: 135/286
# Folder 14 progression: 135/286
# Folder 11 progression: 135/282
# Folder 15 progression: 134/287
# Folder 13 progression: 135/286
# Folder 10 progression: 136/287
# Folder 09 progression: 136/288
# Folder 16 progression: 136/286
# Folder 12 progression: 135/287
# Folder 14 progression: 136/286
# Folder 11 progression: 136/282
# Folder 15 progression: 135/287
# Folder 13 progression: 136/286
# Folder 10 progression: 137/287
# Folder 09 progression: 137/288
# Folder 16 progression: 137/286
# Folder 12 progression: 136/287
# Folder 14 progression: 137/286
# Folder 11 progression: 137/282
# Folder 15 progression: 136/287
# Folder 13 progression: 137/286
# Folder 10 progression: 138/287
# Folder 16 progression: 138/286
# Folder 09 progression: 138/288
# Folder 12 progression: 137/287
# Folder 14 progression: 138/286
# Folder 11 progression: 138/282
# Folder 15 progression: 137/287
# Folder 13 progression: 138/286
# Folder 10 progression: 139/287
# Folder 16 progression: 139/286
# Folder 09 progression: 139/288
# Folder 12 progression: 138/287
# Folder 14 progression: 139/286
# Folder 11 progression: 139/282
# Folder 15 progression: 138/287
# Folder 13 progression: 139/286
# Folder 10 progression: 140/287
# Folder 16 progression: 140/286
# Folder 09 progression: 140/288
# Folder 12 progression: 139/287
# Folder 14 progression: 140/286
# Folder 11 progression: 140/282
# Folder 15 progression: 139/287
# Folder 13 progression: 140/286
# Folder 10 progression: 141/287
# Folder 16 progression: 141/286
# Folder 09 progression: 141/288
# Folder 12 progression: 140/287
# Folder 14 progression: 141/286
# Folder 11 progression: 141/282
# Folder 15 progression: 140/287
# Folder 13 progression: 141/286
# Folder 10 progression: 142/287
# Folder 16 progression: 142/286
# Folder 09 progression: 142/288
# Folder 12 progression: 141/287
# Folder 14 progression: 142/286
# Folder 11 progression: 142/282
# Folder 15 progression: 141/287
# Folder 13 progression: 142/286
# Folder 10 progression: 143/287
# Folder 16 progression: 143/286
# Folder 09 progression: 143/288
# Folder 12 progression: 142/287
# Folder 14 progression: 143/286
# Folder 11 progression: 143/282
# Folder 15 progression: 142/287
# Folder 13 progression: 143/286
# Folder 10 progression: 144/287
# Folder 16 progression: 144/286
# Folder 09 progression: 144/288
# Folder 12 progression: 143/287
# Folder 14 progression: 144/286
# Folder 11 progression: 144/282
# Folder 15 progression: 143/287
# Folder 13 progression: 144/286
# Folder 10 progression: 145/287
# Folder 16 progression: 145/286
# Folder 09 progression: 145/288
# Folder 12 progression: 144/287
# Folder 14 progression: 145/286
# Folder 11 progression: 145/282
# Folder 15 progression: 144/287
# Folder 13 progression: 145/286
# Folder 10 progression: 146/287
# Folder 16 progression: 146/286
# Folder 09 progression: 146/288
# Folder 12 progression: 145/287
# Folder 14 progression: 146/286
# Folder 11 progression: 146/282
# Folder 15 progression: 145/287
# Folder 13 progression: 146/286
# Folder 10 progression: 147/287
# Folder 16 progression: 147/286
# Folder 09 progression: 147/288
# Folder 12 progression: 146/287
# Folder 14 progression: 147/286
# Folder 11 progression: 147/282
# Folder 15 progression: 146/287
# Folder 13 progression: 147/286
# Folder 10 progression: 148/287
# Folder 16 progression: 148/286
# Folder 09 progression: 148/288
# Folder 12 progression: 147/287
# Folder 14 progression: 148/286
# Folder 11 progression: 148/282
# Folder 15 progression: 147/287
# Folder 13 progression: 148/286
# Folder 10 progression: 149/287
# Folder 16 progression: 149/286
# Folder 09 progression: 149/288
# Folder 12 progression: 148/287
# Folder 14 progression: 149/286
# Folder 11 progression: 149/282
# Folder 15 progression: 148/287
# Folder 13 progression: 149/286
# Folder 10 progression: 150/287
# Folder 16 progression: 150/286
# Folder 09 progression: 150/288
# Folder 12 progression: 149/287
# Folder 14 progression: 150/286
# Folder 11 progression: 150/282
# Folder 15 progression: 149/287
# Folder 13 progression: 150/286
# Folder 10 progression: 151/287
# Folder 16 progression: 151/286
# Folder 09 progression: 151/288
# Folder 12 progression: 150/287
# Folder 14 progression: 151/286
# Folder 11 progression: 151/282
# Folder 15 progression: 150/287
# Folder 13 progression: 151/286
# Folder 10 progression: 152/287
# Folder 16 progression: 152/286
# Folder 09 progression: 152/288
# Folder 12 progression: 151/287
# Folder 14 progression: 152/286
# Folder 11 progression: 152/282
# Folder 15 progression: 151/287
# Folder 13 progression: 152/286
# Folder 10 progression: 153/287
# Folder 16 progression: 153/286
# Folder 09 progression: 153/288
# Folder 12 progression: 152/287
# Folder 14 progression: 153/286
# Folder 11 progression: 153/282
# Folder 15 progression: 152/287
# Folder 13 progression: 153/286
# Folder 10 progression: 154/287
# Folder 16 progression: 154/286
# Folder 09 progression: 154/288
# Folder 12 progression: 153/287
# Folder 14 progression: 154/286
# Folder 11 progression: 154/282
# Folder 15 progression: 153/287
# Folder 13 progression: 154/286
# Folder 10 progression: 155/287
# Folder 16 progression: 155/286
# Folder 09 progression: 155/288
# Folder 12 progression: 154/287
# Folder 14 progression: 155/286
# Folder 11 progression: 155/282
# Folder 15 progression: 154/287
# Folder 13 progression: 155/286
# Folder 10 progression: 156/287
# Folder 16 progression: 156/286
# Folder 09 progression: 156/288
# Folder 12 progression: 155/287
# Folder 14 progression: 156/286
# Folder 11 progression: 156/282
# Folder 15 progression: 155/287
# Folder 13 progression: 156/286
# Folder 10 progression: 157/287
# Folder 16 progression: 157/286
# Folder 09 progression: 157/288
# Folder 12 progression: 156/287
# Folder 14 progression: 157/286
# Folder 11 progression: 157/282
# Folder 15 progression: 156/287
# Folder 13 progression: 157/286
# Folder 10 progression: 158/287
# Folder 16 progression: 158/286
# Folder 09 progression: 158/288
# Folder 12 progression: 157/287
# Folder 14 progression: 158/286
# Folder 11 progression: 158/282
# Folder 15 progression: 157/287
# Folder 13 progression: 158/286
# Folder 10 progression: 159/287
# Folder 16 progression: 159/286
# Folder 09 progression: 159/288
# Folder 12 progression: 158/287
# Folder 14 progression: 159/286
# Folder 11 progression: 159/282
# Folder 15 progression: 158/287
# Folder 13 progression: 159/286
# Folder 10 progression: 160/287
# Folder 16 progression: 160/286
# Folder 09 progression: 160/288
# Folder 12 progression: 159/287
# Folder 14 progression: 160/286
# Folder 11 progression: 160/282
# Folder 15 progression: 159/287
# Folder 13 progression: 160/286
# Folder 10 progression: 161/287
# Folder 16 progression: 161/286
# Folder 09 progression: 161/288
# Folder 12 progression: 160/287
# Folder 14 progression: 161/286
# Folder 11 progression: 161/282
# Folder 15 progression: 160/287
# Folder 13 progression: 161/286
# Folder 10 progression: 162/287
# Folder 16 progression: 162/286
# Folder 09 progression: 162/288
# Folder 12 progression: 161/287
# Folder 14 progression: 162/286
# Folder 11 progression: 162/282
# Folder 15 progression: 161/287
# Folder 13 progression: 162/286
# Folder 10 progression: 163/287
# Folder 16 progression: 163/286
# Folder 09 progression: 163/288
# Folder 12 progression: 162/287
# Folder 14 progression: 163/286
# Folder 11 progression: 163/282
# Folder 15 progression: 162/287
# Folder 13 progression: 163/286
# Folder 10 progression: 164/287
# Folder 16 progression: 164/286
# Folder 09 progression: 164/288
# Folder 12 progression: 163/287
# Folder 14 progression: 164/286
# Folder 11 progression: 164/282
# Folder 15 progression: 163/287
# Folder 13 progression: 164/286
# Folder 10 progression: 165/287
# Folder 16 progression: 165/286
# Folder 09 progression: 165/288
# Folder 12 progression: 164/287
# Folder 14 progression: 165/286
# Folder 11 progression: 165/282
# Folder 15 progression: 164/287
# Folder 13 progression: 165/286
# Folder 10 progression: 166/287
# Folder 16 progression: 166/286
# Folder 09 progression: 166/288
# Folder 12 progression: 165/287
# Folder 14 progression: 166/286
# Folder 11 progression: 166/282
# Folder 15 progression: 165/287
# Folder 13 progression: 166/286
# Folder 10 progression: 167/287
# Folder 16 progression: 167/286
# Folder 09 progression: 167/288
# Folder 12 progression: 166/287
# Folder 14 progression: 167/286
# Folder 11 progression: 167/282
# Folder 15 progression: 166/287
# Folder 13 progression: 167/286
# Folder 10 progression: 168/287
# Folder 16 progression: 168/286
# Folder 09 progression: 168/288
# Folder 12 progression: 167/287
# Folder 14 progression: 168/286
# Folder 11 progression: 168/282
# Folder 15 progression: 167/287
# Folder 13 progression: 168/286
# Folder 10 progression: 169/287
# Folder 16 progression: 169/286
# Folder 09 progression: 169/288
# Folder 12 progression: 168/287
# Folder 14 progression: 169/286
# Folder 11 progression: 169/282
# Folder 15 progression: 168/287
# Folder 13 progression: 169/286
# Folder 10 progression: 170/287
# Folder 16 progression: 170/286
# Folder 09 progression: 170/288
# Folder 12 progression: 169/287
# Folder 14 progression: 170/286
# Folder 11 progression: 170/282
# Folder 15 progression: 169/287
# Folder 13 progression: 170/286
# Folder 10 progression: 171/287
# Folder 16 progression: 171/286
# Folder 09 progression: 171/288
# Folder 12 progression: 170/287
# Folder 14 progression: 171/286
# Folder 11 progression: 171/282
# Folder 15 progression: 170/287
# Folder 13 progression: 171/286
# Folder 10 progression: 172/287
# Folder 16 progression: 172/286
# Folder 09 progression: 172/288
# Folder 12 progression: 171/287
# Folder 14 progression: 172/286
# Folder 11 progression: 172/282
# Folder 15 progression: 171/287
# Folder 13 progression: 172/286
# Folder 10 progression: 173/287
# Folder 16 progression: 173/286
# Folder 09 progression: 173/288
# Folder 12 progression: 172/287
# Folder 14 progression: 173/286
# Folder 11 progression: 173/282
# Folder 15 progression: 172/287
# Folder 13 progression: 173/286
# Folder 10 progression: 174/287
# Folder 16 progression: 174/286
# Folder 09 progression: 174/288
# Folder 12 progression: 173/287
# Folder 14 progression: 174/286
# Folder 11 progression: 174/282
# Folder 15 progression: 173/287
# Folder 13 progression: 174/286
# Folder 10 progression: 175/287
# Folder 16 progression: 175/286
# Folder 09 progression: 175/288
# Folder 12 progression: 174/287
# Folder 14 progression: 175/286
# Folder 11 progression: 175/282
# Folder 15 progression: 174/287
# Folder 13 progression: 175/286
# Folder 10 progression: 176/287
# Folder 16 progression: 176/286
# Folder 09 progression: 176/288
# Folder 12 progression: 175/287
# Folder 14 progression: 176/286
# Folder 11 progression: 176/282
# Folder 15 progression: 175/287
# Folder 13 progression: 176/286
# Folder 10 progression: 177/287
# Folder 16 progression: 177/286
# Folder 09 progression: 177/288
# Folder 12 progression: 176/287
# Folder 14 progression: 177/286
# Folder 11 progression: 177/282
# Folder 15 progression: 176/287
# Folder 13 progression: 177/286
# Folder 10 progression: 178/287
# Folder 16 progression: 178/286
# Folder 09 progression: 178/288
# Folder 12 progression: 177/287
# Folder 14 progression: 178/286
# Folder 11 progression: 178/282
# Folder 15 progression: 177/287
# Folder 13 progression: 178/286
# Folder 10 progression: 179/287
# Folder 16 progression: 179/286
# Folder 09 progression: 179/288
# Folder 12 progression: 178/287
# Folder 14 progression: 179/286
# Folder 11 progression: 179/282
# Folder 15 progression: 178/287
# Folder 13 progression: 179/286
# Folder 10 progression: 180/287
# Folder 16 progression: 180/286
# Folder 09 progression: 180/288
# Folder 12 progression: 179/287
# Folder 14 progression: 180/286
# Folder 11 progression: 180/282
# Folder 15 progression: 179/287
# Folder 13 progression: 180/286
# Folder 10 progression: 181/287
# Folder 16 progression: 181/286
# Folder 09 progression: 181/288
# Folder 12 progression: 180/287
# Folder 14 progression: 181/286
# Folder 11 progression: 181/282
# Folder 13 progression: 181/286
# Folder 15 progression: 180/287
# Folder 10 progression: 182/287
# Folder 16 progression: 182/286
# Folder 09 progression: 182/288
# Folder 12 progression: 181/287
# Folder 14 progression: 182/286
# Folder 11 progression: 182/282
# Folder 13 progression: 182/286
# Folder 15 progression: 181/287
# Folder 10 progression: 183/287
# Folder 16 progression: 183/286
# Folder 09 progression: 183/288
# Folder 12 progression: 182/287
# Folder 14 progression: 183/286
# Folder 11 progression: 183/282
# Folder 13 progression: 183/286
# Folder 15 progression: 182/287
# Folder 10 progression: 184/287
# Folder 16 progression: 184/286
# Folder 09 progression: 184/288
# Folder 12 progression: 183/287
# Folder 14 progression: 184/286
# Folder 11 progression: 184/282
# Folder 13 progression: 184/286
# Folder 15 progression: 183/287
# Folder 10 progression: 185/287
# Folder 16 progression: 185/286
# Folder 09 progression: 185/288
# Folder 12 progression: 184/287
# Folder 14 progression: 185/286
# Folder 11 progression: 185/282
# Folder 13 progression: 185/286
# Folder 15 progression: 184/287
# Folder 10 progression: 186/287
# Folder 16 progression: 186/286
# Folder 09 progression: 186/288
# Folder 12 progression: 185/287
# Folder 14 progression: 186/286
# Folder 11 progression: 186/282
# Folder 13 progression: 186/286
# Folder 15 progression: 185/287
# Folder 10 progression: 187/287
# Folder 16 progression: 187/286
# Folder 09 progression: 187/288
# Folder 12 progression: 186/287
# Folder 14 progression: 187/286
# Folder 11 progression: 187/282
# Folder 13 progression: 187/286
# Folder 15 progression: 186/287
# Folder 10 progression: 188/287
# Folder 16 progression: 188/286
# Folder 09 progression: 188/288
# Folder 12 progression: 187/287
# Folder 14 progression: 188/286
# Folder 11 progression: 188/282
# Folder 13 progression: 188/286
# Folder 15 progression: 187/287
# Folder 10 progression: 189/287
# Folder 16 progression: 189/286
# Folder 09 progression: 189/288
# Folder 12 progression: 188/287
# Folder 14 progression: 189/286
# Folder 11 progression: 189/282
# Folder 13 progression: 189/286
# Folder 15 progression: 188/287
# Folder 10 progression: 190/287
# Folder 16 progression: 190/286
# Folder 09 progression: 190/288
# Folder 12 progression: 189/287
# Folder 14 progression: 190/286
# Folder 11 progression: 190/282
# Folder 13 progression: 190/286
# Folder 15 progression: 189/287
# Folder 10 progression: 191/287
# Folder 16 progression: 191/286
# Folder 09 progression: 191/288
# Folder 12 progression: 190/287
# Folder 14 progression: 191/286
# Folder 11 progression: 191/282
# Folder 13 progression: 191/286
# Folder 15 progression: 190/287
# Folder 10 progression: 192/287
# Folder 16 progression: 192/286
# Folder 09 progression: 192/288
# Folder 12 progression: 191/287
# Folder 14 progression: 192/286
# Folder 11 progression: 192/282
# Folder 13 progression: 192/286
# Folder 15 progression: 191/287
# Folder 10 progression: 193/287
# Folder 16 progression: 193/286
# Folder 09 progression: 193/288
# Folder 12 progression: 192/287
# Folder 14 progression: 193/286
# Folder 11 progression: 193/282
# Folder 13 progression: 193/286
# Folder 10 progression: 194/287
# Folder 15 progression: 192/287
# Folder 16 progression: 194/286
# Folder 09 progression: 194/288
# Folder 12 progression: 193/287
# Folder 14 progression: 194/286
# Folder 11 progression: 194/282
# Folder 13 progression: 194/286
# Folder 10 progression: 195/287
# Folder 15 progression: 193/287
# Folder 16 progression: 195/286
# Folder 09 progression: 195/288
# Folder 12 progression: 194/287
# Folder 14 progression: 195/286
# Folder 13 progression: 195/286
# Folder 11 progression: 195/282
# Folder 10 progression: 196/287
# Folder 15 progression: 194/287
# Folder 16 progression: 196/286
# Folder 09 progression: 196/288
# Folder 12 progression: 195/287
# Folder 14 progression: 196/286
# Folder 13 progression: 196/286
# Folder 11 progression: 196/282
# Folder 10 progression: 197/287
# Folder 15 progression: 195/287
# Folder 16 progression: 197/286
# Folder 09 progression: 197/288
# Folder 12 progression: 196/287
# Folder 14 progression: 197/286
# Folder 13 progression: 197/286
# Folder 11 progression: 197/282
# Folder 10 progression: 198/287
# Folder 15 progression: 196/287
# Folder 16 progression: 198/286
# ...
# Folder 16 progression: 223/286
# Folder 11 progression: 222/282
# Folder 15 progression: 221/287
# Folder 12 progression: 222/287
# Folder 09 progression: 223/288
# Folder 14 progression: 223/286
# Folder 13 progression: 223/286
# Folder 10 progression: 224/287
# Folder 16 progression: 224/286
# Folder 11 progression: 223/282
# Folder 15 progression: 222/287
# Folder 12 progression: 223/287
# Folder 09 progression: 224/288
# Folder 14 progression: 224/286
# Folder 13 progression: 224/286
# Folder 10 progression: 225/287
# Folder 16 progression: 225/286
# Folder 11 progression: 224/282
# Folder 15 progression: 223/287
# Folder 12 progression: 224/287
# Folder 09 progression: 225/288
# Folder 14 progression: 225/286
# Folder 13 progression: 225/286
# Folder 10 progression: 226/287
# Folder 16 progression: 226/286
# Folder 11 progression: 225/282
# Folder 15 progression: 224/287
# Folder 12 progression: 225/287
# Folder 09 progression: 226/288
# Folder 14 progression: 226/286
# Folder 13 progression: 226/286
# Folder 10 progression: 227/287
# Folder 16 progression: 227/286
# Folder 11 progression: 226/282
# Folder 15 progression: 225/287
# Folder 12 progression: 226/287
# Folder 09 progression: 227/288
# Folder 14 progression: 227/286
# Folder 13 progression: 227/286
# Folder 10 progression: 228/287
# Folder 16 progression: 228/286
# Folder 11 progression: 227/282
# Folder 15 progression: 226/287
# Folder 12 progression: 227/287
# Folder 09 progression: 228/288
# Folder 14 progression: 228/286
# Folder 13 progression: 228/286
# Folder 10 progression: 229/287
# Folder 16 progression: 229/286
# Folder 11 progression: 228/282
# Folder 15 progression: 227/287
# Folder 12 progression: 228/287
# Folder 09 progression: 229/288
# Folder 14 progression: 229/286
# Folder 13 progression: 229/286
# Folder 10 progression: 230/287
# Folder 16 progression: 230/286
# Folder 11 progression: 229/282
# Folder 15 progression: 228/287
# Folder 12 progression: 229/287
# Folder 09 progression: 230/288
# Folder 14 progression: 230/286
# Folder 13 progression: 230/286
# Folder 10 progression: 231/287
# Folder 16 progression: 231/286
# Folder 11 progression: 230/282
# Folder 15 progression: 229/287
# Folder 12 progression: 230/287
# Folder 09 progression: 231/288
# Folder 14 progression: 231/286
# Folder 13 progression: 231/286
# Folder 10 progression: 232/287
# Folder 16 progression: 232/286
# Folder 11 progression: 231/282
# Folder 15 progression: 230/287
# Folder 12 progression: 231/287
# Folder 09 progression: 232/288
# Folder 14 progression: 232/286
# Folder 13 progression: 232/286
# Folder 10 progression: 233/287
# Folder 16 progression: 233/286
# Folder 11 progression: 232/282
# Folder 15 progression: 231/287
# Folder 12 progression: 232/287
# Folder 09 progression: 233/288
# Folder 14 progression: 233/286
# Folder 13 progression: 233/286
# Folder 10 progression: 234/287
# Folder 16 progression: 234/286
# Folder 11 progression: 233/282
# Folder 15 progression: 232/287
# Folder 12 progression: 233/287
# Folder 14 progression: 234/286
# Folder 09 progression: 234/288
# Folder 13 progression: 234/286
# Folder 10 progression: 235/287
# Folder 16 progression: 235/286
# Folder 11 progression: 234/282
# Folder 15 progression: 233/287
# Folder 12 progression: 234/287
# Folder 14 progression: 235/286
# Folder 09 progression: 235/288
# Folder 13 progression: 235/286
# Folder 16 progression: 236/286
# Folder 10 progression: 236/287
# Folder 11 progression: 235/282
# Folder 15 progression: 234/287
# Folder 12 progression: 235/287
# Folder 14 progression: 236/286
# Folder 09 progression: 236/288
# Folder 13 progression: 236/286
# Folder 16 progression: 237/286
# Folder 10 progression: 237/287
# Folder 11 progression: 236/282
# Folder 15 progression: 235/287
# Folder 12 progression: 236/287
# Folder 14 progression: 237/286
# Folder 09 progression: 237/288
# Folder 13 progression: 237/286
# Folder 16 progression: 238/286
# Folder 10 progression: 238/287
# Folder 11 progression: 237/282
# Folder 15 progression: 236/287
# Folder 12 progression: 237/287
# Folder 14 progression: 238/286
# Folder 09 progression: 238/288
# Folder 13 progression: 238/286
# Folder 16 progression: 239/286
# Folder 10 progression: 239/287
# Folder 11 progression: 238/282
# Folder 15 progression: 237/287
# Folder 12 progression: 238/287
# Folder 14 progression: 239/286
# Folder 09 progression: 239/288
# Folder 13 progression: 239/286
# Folder 16 progression: 240/286
# Folder 10 progression: 240/287
# Folder 11 progression: 239/282
# Folder 15 progression: 238/287
# Folder 12 progression: 239/287
# Folder 14 progression: 240/286
# Folder 09 progression: 240/288
# Folder 13 progression: 240/286
# Folder 16 progression: 241/286
# Folder 10 progression: 241/287
# Folder 11 progression: 240/282
# Folder 15 progression: 239/287
# Folder 12 progression: 240/287
# Folder 14 progression: 241/286
# Folder 09 progression: 241/288
# Folder 13 progression: 241/286
# Folder 16 progression: 242/286
# Folder 10 progression: 242/287
# Folder 11 progression: 241/282
# Folder 15 progression: 240/287
# Folder 12 progression: 241/287
# Folder 14 progression: 242/286
# Folder 09 progression: 242/288
# Folder 13 progression: 242/286
# Folder 16 progression: 243/286
# Folder 10 progression: 243/287
# Folder 11 progression: 242/282
# Folder 15 progression: 241/287
# Folder 12 progression: 242/287
# Folder 14 progression: 243/286
# Folder 09 progression: 243/288
# Folder 16 progression: 244/286
# Folder 13 progression: 243/286
# Folder 10 progression: 244/287
# Folder 11 progression: 243/282
# Folder 15 progression: 242/287
# Folder 12 progression: 243/287
# Folder 14 progression: 244/286
# Folder 09 progression: 244/288
# Folder 13 progression: 244/286
# Folder 16 progression: 245/286
# Folder 10 progression: 245/287
# Folder 11 progression: 244/282
# Folder 15 progression: 243/287
# Folder 12 progression: 244/287
# Folder 14 progression: 245/286
# Folder 09 progression: 245/288
# Folder 13 progression: 245/286
# Folder 16 progression: 246/286
# Folder 10 progression: 246/287
# Folder 11 progression: 245/282
# Folder 15 progression: 244/287
# Folder 12 progression: 245/287
# Folder 14 progression: 246/286
# Folder 09 progression: 246/288
# Folder 13 progression: 246/286
# Folder 16 progression: 247/286
# Folder 10 progression: 247/287
# Folder 11 progression: 246/282
# Folder 15 progression: 245/287
# Folder 12 progression: 246/287
# Folder 14 progression: 247/286
# Folder 09 progression: 247/288
# Folder 13 progression: 247/286
# Folder 16 progression: 248/286
# Folder 10 progression: 248/287
# Folder 11 progression: 247/282
# Folder 15 progression: 246/287
# Folder 12 progression: 247/287
# Folder 14 progression: 248/286
# Folder 09 progression: 248/288
# Folder 13 progression: 248/286
# Folder 16 progression: 249/286
# Folder 10 progression: 249/287
# Folder 11 progression: 248/282
# Folder 15 progression: 247/287
# Folder 12 progression: 248/287
# Folder 14 progression: 249/286
# Folder 09 progression: 249/288
# Folder 13 progression: 249/286
# Folder 16 progression: 250/286
# Folder 10 progression: 250/287
# Folder 11 progression: 249/282
# Folder 15 progression: 248/287
# Folder 12 progression: 249/287
# Folder 14 progression: 250/286
# Folder 09 progression: 250/288
# Folder 13 progression: 250/286
# Folder 16 progression: 251/286
# Folder 10 progression: 251/287
# Folder 11 progression: 250/282
# Folder 15 progression: 249/287
# Folder 12 progression: 250/287
# Folder 14 progression: 251/286
# Folder 09 progression: 251/288
# Folder 13 progression: 251/286
# Folder 16 progression: 252/286
# Folder 10 progression: 252/287
# Folder 11 progression: 251/282
# Folder 15 progression: 250/287
# Folder 12 progression: 251/287
# Folder 14 progression: 252/286
# Folder 09 progression: 252/288
# Folder 13 progression: 252/286
# Folder 16 progression: 253/286
# Folder 10 progression: 253/287
# Folder 11 progression: 252/282
# Folder 15 progression: 251/287
# Folder 12 progression: 252/287
# Folder 14 progression: 253/286
# Folder 09 progression: 253/288
# Folder 13 progression: 253/286
# Folder 16 progression: 254/286
# Folder 10 progression: 254/287
# Folder 11 progression: 253/282
# Folder 15 progression: 252/287
# Folder 12 progression: 253/287
# Folder 14 progression: 254/286
# Folder 09 progression: 254/288
# Folder 13 progression: 254/286
# Folder 16 progression: 255/286
# Folder 10 progression: 255/287
# Folder 11 progression: 254/282
# Folder 15 progression: 253/287
# Folder 12 progression: 254/287
# Folder 14 progression: 255/286
# Folder 09 progression: 255/288
# Folder 13 progression: 255/286
# Folder 16 progression: 256/286
# Folder 10 progression: 256/287
# Folder 11 progression: 255/282
# Folder 15 progression: 254/287
# Folder 14 progression: 256/286
# Folder 12 progression: 255/287
# Folder 09 progression: 256/288
# Folder 13 progression: 256/286
# Folder 16 progression: 257/286
# Folder 10 progression: 257/287
# Folder 11 progression: 256/282
# Folder 15 progression: 255/287
# Folder 14 progression: 257/286
# Folder 12 progression: 256/287
# Folder 09 progression: 257/288
# Folder 13 progression: 257/286
# Folder 16 progression: 258/286
# Folder 10 progression: 258/287
# Folder 11 progression: 257/282
# Folder 15 progression: 256/287
# Folder 14 progression: 258/286
# Folder 12 progression: 257/287
# Folder 09 progression: 258/288
# Folder 13 progression: 258/286
# Folder 16 progression: 259/286
# Folder 10 progression: 259/287
# Folder 11 progression: 258/282
# Folder 15 progression: 257/287
# Folder 14 progression: 259/286
# Folder 12 progression: 258/287
# Folder 09 progression: 259/288
# Folder 13 progression: 259/286
# Folder 16 progression: 260/286
# Folder 10 progression: 260/287
# Folder 11 progression: 259/282
# Folder 15 progression: 258/287
# Folder 14 progression: 260/286
# Folder 12 progression: 259/287
# Folder 09 progression: 260/288
# Folder 13 progression: 260/286
# Folder 16 progression: 261/286
# Folder 10 progression: 261/287
# Folder 11 progression: 260/282
# Folder 15 progression: 259/287
# Folder 14 progression: 261/286
# Folder 12 progression: 260/287
# Folder 09 progression: 261/288
# Folder 13 progression: 261/286
# Folder 16 progression: 262/286
# Folder 10 progression: 262/287
# Folder 11 progression: 261/282
# Folder 15 progression: 260/287
# Folder 14 progression: 262/286
# Folder 12 progression: 261/287
# Folder 09 progression: 262/288
# Folder 13 progression: 262/286
# Folder 16 progression: 263/286
# Folder 10 progression: 263/287
# Folder 11 progression: 262/282
# Folder 15 progression: 261/287
# Folder 14 progression: 263/286
# Folder 12 progression: 262/287
# Folder 09 progression: 263/288
# Folder 13 progression: 263/286
# Folder 16 progression: 264/286
# Folder 10 progression: 264/287
# Folder 11 progression: 263/282
# Folder 15 progression: 262/287
# Folder 14 progression: 264/286
# Folder 12 progression: 263/287
# Folder 09 progression: 264/288
# Folder 16 progression: 265/286
# Folder 13 progression: 264/286
# Folder 10 progression: 265/287
# Folder 11 progression: 264/282
# Folder 15 progression: 263/287
# Folder 14 progression: 265/286
# Folder 12 progression: 264/287
# Folder 09 progression: 265/288
# Folder 16 progression: 266/286
# Folder 13 progression: 265/286
# Folder 10 progression: 266/287
# Folder 15 progression: 264/287
# Folder 11 progression: 265/282
# Folder 14 progression: 266/286
# Folder 12 progression: 265/287
# Folder 09 progression: 266/288
# Folder 16 progression: 267/286
# Folder 13 progression: 266/286
# Folder 10 progression: 267/287
# Folder 15 progression: 265/287
# Folder 11 progression: 266/282
# Folder 14 progression: 267/286
# Folder 12 progression: 266/287
# Folder 09 progression: 267/288
# Folder 16 progression: 268/286
# Folder 13 progression: 267/286
# Folder 10 progression: 268/287
# Folder 15 progression: 266/287
# Folder 11 progression: 267/282
# Folder 14 progression: 268/286
# Folder 12 progression: 267/287
# Folder 09 progression: 268/288
# Folder 16 progression: 269/286
# Folder 13 progression: 268/286
# Folder 10 progression: 269/287
# Folder 15 progression: 267/287
# Folder 11 progression: 268/282
# Folder 14 progression: 269/286
# Folder 12 progression: 268/287
# Folder 09 progression: 269/288
# Folder 16 progression: 270/286
# Folder 13 progression: 269/286
# Folder 10 progression: 270/287
# Folder 15 progression: 268/287
# Folder 14 progression: 270/286
# Folder 11 progression: 269/282
# Folder 12 progression: 269/287
# Folder 09 progression: 270/288
# Folder 16 progression: 271/286
# Folder 13 progression: 270/286
# Folder 10 progression: 271/287
# Folder 15 progression: 269/287
# Folder 14 progression: 271/286
# Folder 11 progression: 270/282
# Folder 12 progression: 270/287
# Folder 09 progression: 271/288
# Folder 16 progression: 272/286
# Folder 13 progression: 271/286
# Folder 10 progression: 272/287
# Folder 15 progression: 270/287
# Folder 14 progression: 272/286
# Folder 12 progression: 271/287
# Folder 11 progression: 271/282
# Folder 09 progression: 272/288
# Folder 16 progression: 273/286
# Folder 13 progression: 272/286
# Folder 10 progression: 273/287
# Folder 15 progression: 271/287
# Folder 14 progression: 273/286
# Folder 12 progression: 272/287
# Folder 11 progression: 272/282
# Folder 09 progression: 273/288
# Folder 16 progression: 274/286
# Folder 13 progression: 273/286
# Folder 10 progression: 274/287
# Folder 15 progression: 272/287
# Folder 14 progression: 274/286
# Folder 12 progression: 273/287
# Folder 11 progression: 273/282
# Folder 16 progression: 275/286
# Folder 09 progression: 274/288
# Folder 13 progression: 274/286
# Folder 10 progression: 275/287
# Folder 15 progression: 273/287
# Folder 14 progression: 275/286
# Folder 12 progression: 274/287
# Folder 11 progression: 274/282
# Folder 16 progression: 276/286
# Folder 09 progression: 275/288
# Folder 13 progression: 275/286
# Folder 10 progression: 276/287
# Folder 15 progression: 274/287
# Folder 14 progression: 276/286
# Folder 12 progression: 275/287
# Folder 11 progression: 275/282
# Folder 16 progression: 277/286
# Folder 09 progression: 276/288
# Folder 13 progression: 276/286
# Folder 10 progression: 277/287
# Folder 15 progression: 275/287
# Folder 14 progression: 277/286
# Folder 12 progression: 276/287
# Folder 16 progression: 278/286
# Folder 11 progression: 276/282
# Folder 09 progression: 277/288
# Folder 10 progression: 278/287
# Folder 13 progression: 277/286
# Folder 14 progression: 278/286
# Folder 15 progression: 276/287
# Folder 12 progression: 277/287
# Folder 16 progression: 279/286
# Folder 11 progression: 277/282
# Folder 09 progression: 278/288
# Folder 10 progression: 279/287
# Folder 13 progression: 278/286
# Folder 14 progression: 279/286
# Folder 15 progression: 277/287
# Folder 12 progression: 278/287
# Folder 16 progression: 280/286
# Folder 11 progression: 278/282
# Folder 09 progression: 279/288
# Folder 13 progression: 279/286
# Folder 10 progression: 280/287
# Folder 14 progression: 280/286
# Folder 15 progression: 278/287
# Folder 12 progression: 279/287
# Folder 16 progression: 281/286
# Folder 11 progression: 279/282
# Folder 09 progression: 280/288
# Folder 13 progression: 280/286
# Folder 10 progression: 281/287
# Folder 14 progression: 281/286
# Folder 15 progression: 279/287
# Folder 12 progression: 280/287
# Folder 16 progression: 282/286
# Folder 11 progression: 280/282
# Folder 09 progression: 281/288
# Folder 10 progression: 282/287
# Folder 13 progression: 281/286
# Folder 14 progression: 282/286
# Folder 15 progression: 280/287
# Folder 12 progression: 281/287
# Folder 16 progression: 283/286
# Folder 09 progression: 282/288
# Folder 11 progression: 281/282
# Folder 10 progression: 283/287
# Folder 13 progression: 282/286
# Folder 14 progression: 283/286
# Folder 15 progression: 281/287
# Folder 12 progression: 282/287
# Folder 16 progression: 284/286
# Folder 11 progression: 282/282
# Folder 09 progression: 283/288
# Folder 10 progression: 284/287
# Folder 13 progression: 283/286
# Folder 14 progression: 284/286
# Folder 15 progression: 282/287
# Folder 12 progression: 283/287
# Folder 16 progression: 285/286
# Folder 09 progression: 284/288
# Folder 10 progression: 285/287
# Folder 13 progression: 284/286
# Folder 14 progression: 285/286
# Folder 15 progression: 283/287
# Folder 12 progression: 284/287
# Folder 16 progression: 286/286
# Folder 09 progression: 285/288
# Folder 10 progression: 286/287
# Folder 13 progression: 285/286
# Folder 14 progression: 286/286
# Folder 15 progression: 284/287
# Folder 12 progression: 285/287
# Folder 09 progression: 286/288
# Folder 10 progression: 287/287
# Folder 13 progression: 286/286
# Folder 15 progression: 285/287
# Folder 12 progression: 286/287
# Folder 09 progression: 287/288
# Folder 15 progression: 286/287
# Folder 12 progression: 287/287
# Folder 09 progression: 288/288
# Folder 15 progression: 287/287

# %%
file = "NLHRW_pvol_20211008T0035_6356.h5"
pc = BirdCloud()
pc.from_odim_file(f"../data/2021/10/08/{file}")
new_name = file.split(".")[0]
new_name = new_name + ".csv"
pc.to_csv(f"../{new_name}")
