# %%
import pandas as pd
import numpy as np
import os

# %%
def find_5min_prior(filename):
    splitname = filename.split("_")
    datetime = splitname[2].split("T")
    newTime = int(datetime[1]) - 5
    print(newTime)
    
    missingZeros = 4 - len(str(newTime))
    
    if missingZeros > 0:
        newTime = "0"*missingZeros + str(newTime)
    
    firstPartNewFile = filename.split("T")[0]

    priorFile = firstPartNewFile + "T" + str(newTime) + "_" + splitname[-1]
    
    return priorFile

# %%
def add_5min_prior(filename):
    prior_file = find_5min_prior(filename)
    print(prior_file)
    print(prior_file in os.listdir("../pointclouds"))
    if prior_file in os.listdir("../pointclouds"):
        print("found file")
        df1 = pd.read_parquet("../pointclouds/"+ filename)
        df1.drop(df1[(df1['x'] == 0) & (df1['y'] == 0)].index, inplace=True)

        df2 = pd.read_parquet("../pointclouds/"+ prior_file)
        df2 = df2.drop('biology', axis=1)
        df2 = df2.rename(columns={'DBZH':'prior_DBZ', 'VRADH':'prior_VRAD'})
        df2.drop(df2[(df2['x'] == 0) & (df2['y'] == 0)].index, inplace=True)

        newDF = pd.merge(df1, df2, how='left', left_on=['x', 'y', 'z'], right_on=['x','y','z'])
        newDF = newDF.fillna(-200)
        newDF.to_parquet("../cloudswithtime/"+ filename)
    else:
        print(filename)

# %%
add_5min_prior("NLHRW_pvol_20211001T0010_6356.parquet")
# Out:
# 5
# NLHRW_pvol_20211001T0005_6356.parquet
# True
# found file

# %%
df = pd.read_parquet("../pointclouds/NLHRW_pvol_20211001T0010_6356.parquet")

# %%
df
# Out:
#                    x         y         z       DBZH      VRADH  biology  \
# 0       5.329537e-18  0.087038  0.051022  -7.521954  21.931314        0
# 1       1.065907e-17  0.174076  0.074343 -19.186355 -27.493224        0
# 2       1.598861e-17  0.261114  0.097665 -31.486397  22.297078        0
# 3       2.664768e-17  0.435190  0.144309   5.181177 -27.507855        0
# 4       3.197722e-17  0.522228  0.167630   7.334217 -22.316437        1
# ...              ...       ...       ...        ...        ...      ...
# 263140 -1.640321e-01  9.397391  3.448598  -1.814750   6.813048        0
# 263141 -1.655098e-01  9.482052  3.479417  -1.134537   7.283665        0
# 263142 -1.669876e-01  9.566713  3.510236  -6.585934   7.637237        0
# 263143 -1.684654e-01  9.651374  3.541055  -8.853312   7.583592        0
# 263144 -1.699431e-01  9.736036  3.571874 -10.062580   7.078837        0
#
#         prior_DBZ  prior_VRAD
# 0       -8.370768   25.108588
# 1      -27.967116   -6.856791
# 2      -30.168604  -19.504927
# 3        4.772274  -74.576869
# 4        6.231535  -23.179641
# ...           ...         ...
# 263140  -7.820395    5.210999
# 263141  -8.171161    6.252209
# 263142  -5.810762    6.252209
# 263143  -4.084066    6.725264
# 263144  -5.186749    6.998368
#
# [263145 rows x 8 columns]
